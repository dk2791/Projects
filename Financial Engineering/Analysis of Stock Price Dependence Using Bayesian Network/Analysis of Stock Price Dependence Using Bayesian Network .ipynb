# %% [markdown]
# ### Network Structure from daily close price

# %% [markdown]
# #### This slide shows the result of implementing Bayesian Network on stock prices. I used numpy and pandas on daily close prices of S&P500 companies and a few daily economic data available from FRB.
# 1. I omitted 5 stocks that significantly reduced available timepoints of data such as `Corteva` with ticker symbol`CTVA`. `Corteva` was founded in 2019.
# 2. Data used for creating this output consist mainly of daily close prices from `2011-11-11` to `2019-12-31`.
# 3. For each row, I ranked the most valuable edge. For example. `MS_child` has `BAC_parent` in the first column, `JPM_parent` in the second column, and `GS_parent` in the third column. This means that my model believes `Morgan Stanley` was the closest stock to `Bank of America`, then `JP Morgan` and then `Goldman Sachs`.
# 4. I approximated the score function so it took `1 minute` to run the model on my personal laptop

# %%
import pandas as pd
df = pd.read_csv('contribution_rank.csv',index_col=0)
df.loc['MSFT_child':'MS_child']
# Out:
#                       0            1             2            3            4  \
# MSFT_child    MA_parent     V_parent  GOOGL_parent  GOOG_parent  ADBE_parent
# MAA_child    UDR_parent   AIV_parent    AVB_parent   EQR_parent   ESS_parent
# MHK_child   FBHS_parent   MAS_parent    LEG_parent   SWK_parent   WRK_parent
# TAP_child    UNM_parent  MDLZ_parent     KO_parent  GILD_parent  BF-B_parent
# MDLZ_child   PEP_parent   GIS_parent     CL_parent     K_parent   HSY_parent
# MNST_child   MTD_parent   PEP_parent   PAYX_parent  MDLZ_parent  MSFT_parent
# MCO_child   SPGI_parent    MA_parent      V_parent  MSCI_parent   ACN_parent
# MS_child     BAC_parent   JPM_parent     GS_parent     C_parent   LNC_parent
#
#                       5            6            7            8            9  \
# MSFT_child  AMZN_parent   CRM_parent  INTU_parent  SNPS_parent   ACN_parent
# MAA_child      O_parent   ARE_parent   DRE_parent   PLD_parent  WELL_parent
# MHK_child    EMN_parent   AOS_parent    FB_parent   ITW_parent   PKG_parent
# TAP_child    PFG_parent   GIS_parent    EL_parent   PRU_parent     L_parent
# MDLZ_child    PG_parent   KMB_parent    KO_parent   MKC_parent   SJM_parent
# MNST_child   PKI_parent   ACN_parent     V_parent   BLK_parent    KO_parent
# MCO_child   MSFT_parent  TROW_parent   BLK_parent   AXP_parent  INTU_parent
# MS_child     RJF_parent   KEY_parent   PRU_parent   PNC_parent   CFG_parent
#
#             ...                  516                  517  \
# MSFT_child  ...          ANET_parent            MU_parent
# MAA_child   ...          NVDA_parent          ANET_parent
# MHK_child   ...  DCOILBRENTEU_parent           LNT_parent
# TAP_child   ...          DAAA_parent          MKTX_parent
# MDLZ_child  ...            UA_parent          ALGN_parent
# MNST_child  ...          DBAA_parent  DCOILBRENTEU_parent
# MCO_child   ...          ANET_parent           UAA_parent
# MS_child    ...           HSY_parent       DEXUSUK_parent
#
#                                 518                      519             520  \
# MSFT_child                UA_parent               UAA_parent     TWTR_parent
# MAA_child                NWL_parent               AMD_parent      UAA_parent
# MHK_child                UHS_parent  GOLDAMGBD228NLBM_parent       SO_parent
# TAP_child             DGS3MO_parent              DTB3_parent  DEXJPUS_parent
# MDLZ_child              NVDA_parent              COTY_parent       MU_parent
# MNST_child  GOLDPMGBD228NLBM_parent           DEXSDUS_parent  DEXUSUK_parent
# MCO_child                 UA_parent                MU_parent     TWTR_parent
# MS_child                 ATO_parent               CCI_parent      PPL_parent
#
#                                 521            522            523  \
# MSFT_child              NVDA_parent     AMD_parent  VXDCLS_parent
# MAA_child               ALGN_parent      UA_parent  VXDCLS_parent
# MHK_child               DTB3_parent  DGS3MO_parent  VXDCLS_parent
# TAP_child              TB1YR_parent     AMD_parent  VXDCLS_parent
# MDLZ_child               NWL_parent     AMD_parent  VXDCLS_parent
# MNST_child  GOLDAMGBD228NLBM_parent     AMD_parent  VXDCLS_parent
# MCO_child               NVDA_parent     AMD_parent  VXDCLS_parent
# MS_child                 UAA_parent     AMD_parent  VXDCLS_parent
#
#                       524          525
# MSFT_child  VIXCLS_parent  MSFT_parent
# MAA_child   VIXCLS_parent   MAA_parent
# MHK_child   VIXCLS_parent   MHK_parent
# TAP_child   VIXCLS_parent   TAP_parent
# MDLZ_child  VIXCLS_parent  MDLZ_parent
# MNST_child  VIXCLS_parent  MNST_parent
# MCO_child   VIXCLS_parent   MCO_parent
# MS_child    VIXCLS_parent    MS_parent
#
# [8 rows x 526 columns]

# %% [markdown]
# #### I will present a few other sample outcomes below:

# %%
labels = pd.read_csv('./data/stock_label.csv',index_col=0)

# %% [markdown]
# ### 1. Microsoft, `MSFT`

# %%
stock = 'MSFT'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to MSFT are:
#     Symbol              Security SEC filings             GICS Sector  \
# 6     ADBE     Adobe Systems Inc     reports  Information Technology
# 24   GOOGL  Alphabet Inc Class A     reports  Communication Services
# 25    GOOG  Alphabet Inc Class C     reports  Communication Services
# 310     MA       Mastercard Inc.     reports  Information Technology
# 474      V             Visa Inc.     reports  Information Technology
#
#                          GICS Sub Industry      Headquarters Location  \
# 6                     Application Software       San Jose, California
# 24            Interactive Media & Services  Mountain View, California
# 25            Interactive Media & Services  Mountain View, California
# 310  Data Processing & Outsourced Services         Harrison, New York
# 474  Data Processing & Outsourced Services  San Francisco, California
#
#     Date first added      CIK Founded
# 6         1997-05-05   796343    1982
# 24        2014-04-03  1652044    1998
# 25        2006-04-03  1652044    1998
# 310       2008-07-18  1141391     NaN
# 474       2009-12-21  1403161     NaN

# %% [markdown]
# ### 2. Exxon Mobil Corporation, `XOM`

# %%
stock = 'XOM'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to XOM are:
#     Symbol           Security SEC filings GICS Sector  \
# 103    CVX      Chevron Corp.     reports      Energy
# 278    KMI      Kinder Morgan     reports      Energy
# 361    OKE              ONEOK     reports      Energy
# 375    PSX        Phillips 66     reports      Energy
# 412    SLB  Schlumberger Ltd.     reports      Energy
#
#                       GICS Sub Industry                Headquarters Location  \
# 103                Integrated Oil & Gas                San Ramon, California
# 278  Oil & Gas Storage & Transportation                       Houston, Texas
# 361  Oil & Gas Storage & Transportation                      Tulsa, Oklahoma
# 375      Oil & Gas Refining & Marketing                       Houston, Texas
# 412      Oil & Gas Equipment & Services  Curaçao, Kingdom of the Netherlands
#
#     Date first added      CIK Founded
# 103              NaN    93410    1879
# 278       2012-05-25  1506307     NaN
# 361       2010-03-15  1039684     NaN
# 375       2012-05-01  1534701     NaN
# 412       1965-03-31    87347    1926

# %% [markdown]
# ### 3. Lockheed Martin Corporation, `LMT`

# %%
stock = 'LMT'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to LMT are:
#     Symbol               Security SEC filings  GICS Sector  \
# 211     GD       General Dynamics     reports  Industrials
# 284    LHX  L3Harris Technologies     reports  Industrials
# 350    NOC       Northrop Grumman     reports  Industrials
# 396    RTN           Raytheon Co.     reports  Industrials
# 462    UTX    United Technologies     reports  Industrials
#
#        GICS Sub Industry        Headquarters Location Date first added  \
# 211  Aerospace & Defense       Falls Church, Virginia              NaN
# 284  Aerospace & Defense           Melbourne, Florida              NaN
# 350  Aerospace & Defense  West Falls Church, Virginia       1985-06-30
# 396  Aerospace & Defense       Waltham, Massachusetts              NaN
# 462  Aerospace & Defense        Hartford, Connecticut              NaN
#
#          CIK Founded
# 211    40533    1899
# 284   202058     NaN
# 350  1133421     NaN
# 396  1047122    1922
# 462   101829     NaN

# %% [markdown]
# ### 4. Bank of America, `BAC`

# %%
stock = 'BAC'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to BAC are:
#     Symbol                 Security SEC filings GICS Sector  \
# 112      C           Citigroup Inc.     reports  Financials
# 219     GS      Goldman Sachs Group     reports  Financials
# 270    JPM     JPMorgan Chase & Co.     reports  Financials
# 329     MS           Morgan Stanley     reports  Financials
# 400     RF  Regions Financial Corp.     reports  Financials
#
#                   GICS Sub Industry Headquarters Location Date first added  \
# 112               Diversified Banks    New York, New York       1988-05-31
# 219  Investment Banking & Brokerage    New York, New York       2002-07-22
# 270               Diversified Banks    New York, New York       1975-06-30
# 329  Investment Banking & Brokerage    New York, New York              NaN
# 400                  Regional Banks   Birmingham, Alabama       1998-08-28
#
#          CIK Founded
# 112   831001     NaN
# 219   886982     NaN
# 270    19617     NaN
# 329   895421    1935
# 400  1281761     NaN

# %% [markdown]
# ### 5. Walmart, `WMT`

# %%
stock = 'WMT'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to WMT are:
#     Symbol                Security SEC filings             GICS Sector  \
# 132   COST  Costco Wholesale Corp.     reports        Consumer Staples
# 152     DG          Dollar General     reports  Consumer Discretionary
# 237     HD              Home Depot     reports  Consumer Discretionary
# 326   MDLZ  Mondelez International     reports        Consumer Staples
# 370    PEP            PepsiCo Inc.     reports        Consumer Staples
#
#                 GICS Sub Industry      Headquarters Location Date first added  \
# 132  Hypermarkets & Super Centers       Issaquah, Washington       1993-10-01
# 152    General Merchandise Stores  Goodlettsville, Tennessee       2012-12-03
# 237       Home Improvement Retail           Atlanta, Georgia       1988-03-31
# 326        Packaged Foods & Meats        Deerfield, Illinois       2012-10-02
# 370                   Soft Drinks         Purchase, New York              NaN
#
#          CIK Founded
# 132   909832     NaN
# 152    29534     NaN
# 237   354950     NaN
# 326  1103982     NaN
# 370    77476    1898

# %% [markdown]
# ### 6. Advanced Micro Devices, Inc., `AMD`

# %%
stock = 'AMD'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to AMD are:
#     Symbol                Security SEC filings             GICS Sector  \
# 49    AMAT  Applied Materials Inc.     reports  Information Technology
# 286   LRCX            Lam Research     reports  Information Technology
# 320   MCHP    Microchip Technology     reports  Information Technology
# 321     MU       Micron Technology     reports  Information Technology
# 355   NVDA      Nvidia Corporation     reports  Information Technology
#
#            GICS Sub Industry    Headquarters Location Date first added  \
# 49   Semiconductor Equipment  Santa Clara, California       1995-03-16
# 286  Semiconductor Equipment      Fremont, California       2012-06-29
# 320           Semiconductors        Chandler, Arizona       2007-09-07
# 321           Semiconductors             Boise, Idaho       1994-09-27
# 355           Semiconductors  Santa Clara, California       2001-11-30
#
#          CIK Founded
# 49      6951    1967
# 286   707549     NaN
# 320   827054     NaN
# 321   723125     NaN
# 355  1045810     NaN

# %% [markdown]
# ### 7. Alliant Energy Corp, `LNT`

# %%
stock = 'LNT'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to LNT are:
#     Symbol                 Security SEC filings GICS Sector  \
# 29     AEE              Ameren Corp     reports   Utilities
# 31     AEP  American Electric Power     reports   Utilities
# 117    CMS               CMS Energy     reports   Utilities
# 484    WEC     Wec Energy Group Inc     reports   Utilities
# 496    XEL          Xcel Energy Inc     reports   Utilities
#
#       GICS Sub Industry   Headquarters Location Date first added      CIK  \
# 29      Multi-Utilities     St. Louis, Missouri       1991-09-19  1002910
# 31   Electric Utilities          Columbus, Ohio              NaN     4904
# 117     Multi-Utilities       Jackson, Michigan       1999-05-03   811156
# 484  Electric Utilities    Milwaukee, Wisconsin       2008-10-31   783325
# 496     Multi-Utilities  Minneapolis, Minnesota              NaN    72903
#
#     Founded
# 29     1902
# 31     1906
# 117     NaN
# 484     NaN
# 496    1909

# %% [markdown]
# ### 8. Cigna Corp, `CI`

# %%
stock = 'CI'
parents = df.loc[f'{stock}_child',:].str.split('_').apply(lambda x: x[0]).values[:5]
print(f'stocks closest to {stock} are: ')
labels[labels['Symbol'].isin(parents)]
# Out:
# stocks closest to CI are:
#     Symbol                  Security SEC filings  GICS Sector  \
# 43    ANTM                    Anthem     reports  Health Care
# 96     CNC       Centene Corporation     reports  Health Care
# 242    HUM               Humana Inc.     reports  Health Care
# 459    UNH  United Health Group Inc.     reports  Health Care
# 485    WCG                  WellCare     reports  Health Care
#
#        GICS Sub Industry  Headquarters Location Date first added      CIK  \
# 43   Managed Health Care  Indianapolis, Indiana       2002-07-25  1156039
# 96   Managed Health Care     St Louis, Missouri       2016-03-30  1071739
# 242  Managed Health Care   Louisville, Kentucky              NaN    49071
# 459  Managed Health Care  Minnetonka, Minnesota       1994-07-01   731766
# 485  Managed Health Care         Tampa, Florida             1985  1279363
#
#           Founded
# 43   2014 (1940s)
# 96            NaN
# 242          1961
# 459           NaN
# 485           NaN

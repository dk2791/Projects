# %% [markdown]
# ### 1. Separable Returns
# This results is show a pairplot of various stock returns classified as the same group according to the Network result. I find this result to be remarkable. I was able introduce `lnt_feature_extract2` function to separate distribution of positive and negative returns for returns on `LNT`, `AEE`, `CMS`, `WEC`, and `XEL`. This means that rather than trying to search for prediction model for individual stock, I only need to come up with a significant signal from any one of the stock. In other words, suppose my model for `LNT` stock gives a great prediction accuracy based on labels generated by `lnt_feature_extract2`, then the model will be useful for predicting whether stock returns will be positive or negative for `AEE`, `CMS`, `WEC`, and `XEL`.

# %%
feature_explore['LNT_feature']=feature_explore.iloc[:,1].apply(lnt_feature_extract2)
sns.pairplot(feature_explore, hue='LNT_feature',x_vars=['LNT_y','AEE_y','CMS_y','WEC_y','XEL_y'],y_vars=['LNT_y','AEE_y','CMS_y','WEC_y','XEL_y'])
